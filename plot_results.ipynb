# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def load_data(suffix):
    path = 'results/for_elizabeth/jan_2024/' + suffix
    return np.loadtxt(path)

# %%
etkf = load_data('rmserror_etkf_obs_spacing_exp_uniform2.txt')
estkf = load_data('rmserror_estkf_obs_spacing_exp_uniform2.txt')

# %%
plt.semilogy(etkf)
plt.semilogy(estkf)
plt.show()
